# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

# %%
data = pd.read_csv('/content/Bank_customer_data.csv')

print(data.head())
# Out:
#    ID  Age  Experience  Income  Zipcode  Family    CCAvg  Education  Mortgage  \
# 0   1   39          14  127000    49560       1   567.28          2     36000
# 1   2   36           0   72000    63865       1  3927.17          1    341000
# 2   3   37           5  147000    56686       2   369.79          1    326000
# 3   4   55           4  199000    85910       4  3847.52          3    406000
# 4   5   45          17  177000    14675       1    26.63          2    424000
#
#    Securities Account  CD Account  Online  CreditCard  Personal Loan
# 0                   1           0       1           0              1
# 1                   1           0       0           0              0
# 2                   0           0       0           1              0
# 3                   0           0       0           0              0
# 4                   0           0       0           0              0

# %%
# Drop unnecessary columns
data.drop(columns=['ID', 'Zipcode'], inplace=True)

# Define target variable (y) and features (X)
y = data['Personal Loan']
X = data.drop(columns=['Personal Loan'])

# Encode categorical variable (Education)
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_edu = pd.DataFrame(encoder.fit_transform(data[['Education']]), columns=encoder.get_feature_names_out(['Education']))

# Drop original 'Education' column and add encoded values
X = X.drop(columns=['Education'])
X = pd.concat([X, encoded_edu], axis=1)

# %%
# Scale numerical features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Split data into training & testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"Training Data Shape: {X_train.shape}, Test Data Shape: {X_test.shape}")
# Out:
# Training Data Shape: (400, 12), Test Data Shape: (100, 12)

# %%
# Define the model

model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model

test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5452 - loss: 0.6925 - val_accuracy: 0.8300 - val_loss: 0.5476
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8498 - loss: 0.4950 - val_accuracy: 0.8400 - val_loss: 0.4670
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8561 - loss: 0.4183 - val_accuracy: 0.8400 - val_loss: 0.4586
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8528 - loss: 0.3905 - val_accuracy: 0.8400 - val_loss: 0.4582
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8841 - loss: 0.3371 - val_accuracy: 0.8400 - val_loss: 0.4518
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8557 - loss: 0.3931 - val_accuracy: 0.8400 - val_loss: 0.4451
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8559 - loss: 0.3705 - val_accuracy: 0.8400 - val_loss: 0.4457
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8562 - loss: 0.3634 - val_accuracy: 0.8400 - val_loss: 0.4455
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8391 - loss: 0.3907 - val_accuracy: 0.8400 - val_loss: 0.4451
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8430 - loss: 0.3674 - val_accuracy: 0.8400 - val_loss: 0.4448
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8703 - loss: 0.3188 - val_accuracy: 0.8400 - val_loss: 0.4443
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8772 - loss: 0.3024 - val_accuracy: 0.8400 - val_loss: 0.4389
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8646 - loss: 0.3391 - val_accuracy: 0.8400 - val_loss: 0.4385
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8354 - loss: 0.3691 - val_accuracy: 0.8400 - val_loss: 0.4385
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8337 - loss: 0.3546 - val_accuracy: 0.8400 - val_loss: 0.4378
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.